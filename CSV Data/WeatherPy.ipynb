# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "tweet.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 636

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="  
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=134666dd0e2cc872e1f9ae630e853b34&units=Imperial&q='

# %%
# Add columns for lat, cloudiness, country, temp, date, humidity, lng, max temp, wind speed
cities_data=pd.DataFrame(cities)
cities_data['Cloudiness']=""
cities_data['Country']=""
cities_data['Lat']=""
cities_data['Lng']=" "
cities_data['Date']=""
cities_data['Humidity']=""
cities_data['Max temp']=""
cities_data['Wind speed']=""

cities_data = cities_data.rename(columns={0: "City name"})

# %%
print("Beginning Data Complete")
print("-------------------------")

# use iterrows to iterate through pandas dataframe
for index, row in cities_data.iterrows():
    city = row['City name']
    
    response = requests.get(query_url + city).json()
    
    try:
        
        print(f"Processing Record {index} Of Set {index}| {city}.")
        
        cities_data.loc[index,'City name'] = response ['name']
        cities_data.loc[index,'Cloudiness'] = response ['clouds']['all']
        cities_data.loc[index,'Country'] = response ['sys']['country']
        cities_data.loc[index,'Lat'] = response ['coord']['lat']
        cities_data.loc[index,'Lng'] = response ['coord']['lon']
        cities_data.loc[index,'Date'] = response ['dt']
        cities_data.loc[index,'Humidity'] = response ['main']['humidity']
        cities_data.loc[index,'Max temp'] = response ['main']['temp_max']
        cities_data.loc[index,'Wind speed'] = response ['wind']['speed']
        

    except (KeyError, IndexError):
        print("City Not Found. Skipping.")
        
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Complete
# -------------------------
# Processing Record 0 Of Set 0| dikson.
# Processing Record 1 Of Set 1| emerald.
# Processing Record 2 Of Set 2| falealupo.
# City Not Found. Skipping.
# Processing Record 3 Of Set 3| ketchikan.
# Processing Record 4 Of Set 4| vaitupu.
# City Not Found. Skipping.
# Processing Record 5 Of Set 5| quelimane.
# Processing Record 6 Of Set 6| cabo san lucas.
# Processing Record 7 Of Set 7| cayenne.
# Processing Record 8 Of Set 8| tevaitoa.
# Processing Record 9 Of Set 9| avera.
# Processing Record 10 Of Set 10| biskamzha.
# Processing Record 11 Of Set 11| hammerfest.
# Processing Record 12 Of Set 12| kahului.
# Processing Record 13 Of Set 13| richards bay.
# Processing Record 14 Of Set 14| ushuaia.
# Processing Record 15 Of Set 15| mataura.
# Processing Record 16 Of Set 16| souillac.
# Processing Record 17 Of Set 17| atuona.
# Processing Record 18 Of Set 18| yellowknife.
# Processing Record 19 Of Set 19| kapaa.
# Processing Record 20 Of Set 20| rosarito.
# Processing Record 21 Of Set 21| illoqqortoormiut.
# City Not Found. Skipping.
# Processing Record 22 Of Set 22| moree.
# Processing Record 23 Of Set 23| portland.
# Processing Record 24 Of Set 24| kruisfontein.
# Processing Record 25 Of Set 25| ilulissat.
# Processing Record 26 Of Set 26| manyana.
# Processing Record 27 Of Set 27| egvekinot.
# Processing Record 28 Of Set 28| bluff.
# Processing Record 29 Of Set 29| cidreira.
# Processing Record 30 Of Set 30| hilo.
# Processing Record 31 Of Set 31| goundam.
# Processing Record 32 Of Set 32| son la.
# Processing Record 33 Of Set 33| san vicente de canete.
# Processing Record 34 Of Set 34| tiksi.
# Processing Record 35 Of Set 35| sanandaj.
# Processing Record 36 Of Set 36| charters towers.
# Processing Record 37 Of Set 37| payakumbuh.
# Processing Record 38 Of Set 38| chillicothe.
# Processing Record 39 Of Set 39| torbay.
# Processing Record 40 Of Set 40| olinda.
# Processing Record 41 Of Set 41| anadyr.
# Processing Record 42 Of Set 42| bumba.
# Processing Record 43 Of Set 43| geraldton.
# Processing Record 44 Of Set 44| pimenta bueno.
# Processing Record 45 Of Set 45| leshukonskoye.
# Processing Record 46 Of Set 46| saint george.
# Processing Record 47 Of Set 47| laguna.
# Processing Record 48 Of Set 48| avarua.
# Processing Record 49 Of Set 49| srednekolymsk.
# Processing Record 50 Of Set 50| san cristobal.
# Processing Record 51 Of Set 51| attawapiskat.
# City Not Found. Skipping.
# Processing Record 52 Of Set 52| taolanaro.
# City Not Found. Skipping.
# Processing Record 53 Of Set 53| diego de almagro.
# Processing Record 54 Of Set 54| new norfolk.
# Processing Record 55 Of Set 55| rio gallegos.
# Processing Record 56 Of Set 56| karaul.
# City Not Found. Skipping.
# Processing Record 57 Of Set 57| hermanus.
# Processing Record 58 Of Set 58| rikitea.
# Processing Record 59 Of Set 59| palabuhanratu.
# City Not Found. Skipping.
# Processing Record 60 Of Set 60| bredasdorp.
# Processing Record 61 Of Set 61| sabang.
# Processing Record 62 Of Set 62| busselton.
# Processing Record 63 Of Set 63| vaitape.
# Processing Record 64 Of Set 64| saleaula.
# City Not Found. Skipping.
# Processing Record 65 Of Set 65| grand gaube.
# Processing Record 66 Of Set 66| soliera.
# Processing Record 67 Of Set 67| kutum.
# Processing Record 68 Of Set 68| esperance.
# Processing Record 69 Of Set 69| teseney.
# Processing Record 70 Of Set 70| bethel.
# Processing Record 71 Of Set 71| birao.
# Processing Record 72 Of Set 72| dingle.
# Processing Record 73 Of Set 73| chipiona.
# Processing Record 74 Of Set 74| cape town.
# Processing Record 75 Of Set 75| saskylakh.
# Processing Record 76 Of Set 76| bengkulu.
# City Not Found. Skipping.
# Processing Record 77 Of Set 77| yulara.
# Processing Record 78 Of Set 78| chokurdakh.
# Processing Record 79 Of Set 79| sitka.
# Processing Record 80 Of Set 80| mys shmidta.
# City Not Found. Skipping.
# Processing Record 81 Of Set 81| waipawa.
# Processing Record 82 Of Set 82| belushya guba.
# City Not Found. Skipping.
# Processing Record 83 Of Set 83| jamestown.
# Processing Record 84 Of Set 84| koungou.
# City Not Found. Skipping.
# Processing Record 85 Of Set 85| kyaikto.
# Processing Record 86 Of Set 86| guerrero negro.
# Processing Record 87 Of Set 87| vaini.
# Processing Record 88 Of Set 88| chicama.
# Processing Record 89 Of Set 89| lavrentiya.
# Processing Record 90 Of Set 90| albany.
# Processing Record 91 Of Set 91| krasnoselkup.
# City Not Found. Skipping.
# Processing Record 92 Of Set 92| omagh.
# Processing Record 93 Of Set 93| victoria.
# Processing Record 94 Of Set 94| punta arenas.
# Processing Record 95 Of Set 95| nizhneyansk.
# City Not Found. Skipping.
# Processing Record 96 Of Set 96| ormara.
# Processing Record 97 Of Set 97| lompoc.
# Processing Record 98 Of Set 98| mahebourg.
# Processing Record 99 Of Set 99| puerto ayora.
# Processing Record 100 Of Set 100| lorengau.
# Processing Record 101 Of Set 101| castro.
# Processing Record 102 Of Set 102| la tuque.
# Processing Record 103 Of Set 103| te anau.
# Processing Record 104 Of Set 104| tonder.
# Processing Record 105 Of Set 105| arraial do cabo.
# Processing Record 106 Of Set 106| barrow.
# Processing Record 107 Of Set 107| pevek.
# Processing Record 108 Of Set 108| blagoyevo.
# Processing Record 109 Of Set 109| ust-uda.
# Processing Record 110 Of Set 110| ribeira grande.
# Processing Record 111 Of Set 111| saint anthony.
# Processing Record 112 Of Set 112| kinablangan.
# Processing Record 113 Of Set 113| nome.
# Processing Record 114 Of Set 114| gayny.
# Processing Record 115 Of Set 115| butaritari.
# Processing Record 116 Of Set 116| north bend.
# Processing Record 117 Of Set 117| shitanjing.
# Processing Record 118 Of Set 118| lolua.
# City Not Found. Skipping.
# Processing Record 119 Of Set 119| guarapari.
# Processing Record 120 Of Set 120| namibe.
# Processing Record 121 Of Set 121| quatre cocos.
# Processing Record 122 Of Set 122| vao.
# Processing Record 123 Of Set 123| riaba.
# City Not Found. Skipping.
# Processing Record 124 Of Set 124| georgetown.
# Processing Record 125 Of Set 125| bathurst.
# Processing Record 126 Of Set 126| atbasar.
# Processing Record 127 Of Set 127| kavaratti.
# Processing Record 128 Of Set 128| liwale.
# Processing Record 129 Of Set 129| sao manuel.
# Processing Record 130 Of Set 130| cabedelo.
# Processing Record 131 Of Set 131| itacoatiara.
# Processing Record 132 Of Set 132| port alfred.
# Processing Record 133 Of Set 133| kjollefjord.
# Processing Record 134 Of Set 134| nianzishan.
# Processing Record 135 Of Set 135| kristiinankaupunki.
# City Not Found. Skipping.
# Processing Record 136 Of Set 136| iqaluit.
# Processing Record 137 Of Set 137| carutapera.
# Processing Record 138 Of Set 138| pisco.
# Processing Record 139 Of Set 139| acapulco.
# Processing Record 140 Of Set 140| hobart.
# Processing Record 141 Of Set 141| grand river south east.
# City Not Found. Skipping.
# Processing Record 142 Of Set 142| voi.
# Processing Record 143 Of Set 143| povenets.
# Processing Record 144 Of Set 144| ponta do sol.
# Processing Record 145 Of Set 145| mount isa.
# Processing Record 146 Of Set 146| amla.
# Processing Record 147 Of Set 147| airai.
# Processing Record 148 Of Set 148| lata.
# Processing Record 149 Of Set 149| mopti.
# Processing Record 150 Of Set 150| raudeberg.
# Processing Record 151 Of Set 151| taoudenni.
# Processing Record 152 Of Set 152| severo-kurilsk.
# Processing Record 153 Of Set 153| salalah.
# Processing Record 154 Of Set 154| torquay.
# Processing Record 155 Of Set 155| narsaq.
# Processing Record 156 Of Set 156| norman wells.
# Processing Record 157 Of Set 157| kodiak.
# Processing Record 158 Of Set 158| mitsamiouli.
# Processing Record 159 Of Set 159| upernavik.
# Processing Record 160 Of Set 160| sassandra.
# Processing Record 161 Of Set 161| qui nhon.
# City Not Found. Skipping.
# Processing Record 162 Of Set 162| henties bay.
# Processing Record 163 Of Set 163| lincoln.
# Processing Record 164 Of Set 164| belaya gora.
# Processing Record 165 Of Set 165| vila franca do campo.
# Processing Record 166 Of Set 166| kenai.
# Processing Record 167 Of Set 167| lagoa.
# Processing Record 168 Of Set 168| bambous virieux.
# Processing Record 169 Of Set 169| lahij.
# Processing Record 170 Of Set 170| tuktoyaktuk.
# Processing Record 171 Of Set 171| tabou.
# Processing Record 172 Of Set 172| kangaatsiaq.
# Processing Record 173 Of Set 173| suez.
# Processing Record 174 Of Set 174| santa rosa.
# Processing Record 175 Of Set 175| luderitz.
# Processing Record 176 Of Set 176| aguimes.
# Processing Record 177 Of Set 177| miri.
# Processing Record 178 Of Set 178| faanui.
# Processing Record 179 Of Set 179| port elizabeth.
# Processing Record 180 Of Set 180| ilheus.
# Processing Record 181 Of Set 181| padang.
# Processing Record 182 Of Set 182| barawe.
# City Not Found. Skipping.
# Processing Record 183 Of Set 183| aykhal.
# Processing Record 184 Of Set 184| samalaeulu.
# City Not Found. Skipping.
# Processing Record 185 Of Set 185| sibu.
# Processing Record 186 Of Set 186| bacolod.
# Processing Record 187 Of Set 187| sao joao da barra.
# Processing Record 188 Of Set 188| kalmunai.
# Processing Record 189 Of Set 189| atambua.
# Processing Record 190 Of Set 190| bilibino.
# Processing Record 191 Of Set 191| erdaojiang.
# Processing Record 192 Of Set 192| nishihara.
# Processing Record 193 Of Set 193| evanston.
# Processing Record 194 Of Set 194| prachin buri.
# Processing Record 195 Of Set 195| saint-philippe.
# Processing Record 196 Of Set 196| gravdal.
# Processing Record 197 Of Set 197| sur.
# Processing Record 198 Of Set 198| vastervik.
# City Not Found. Skipping.
# Processing Record 199 Of Set 199| weatherford.
# Processing Record 200 Of Set 200| marawi.
# Processing Record 201 Of Set 201| qiongshan.
# Processing Record 202 Of Set 202| vila velha.
# Processing Record 203 Of Set 203| skelleftea.
# Processing Record 204 Of Set 204| praia da vitoria.
# Processing Record 205 Of Set 205| gat.
# Processing Record 206 Of Set 206| taburi.
# City Not Found. Skipping.
# Processing Record 207 Of Set 207| deulgaon raja.
# Processing Record 208 Of Set 208| carahue.
# Processing Record 209 Of Set 209| warqla.
# City Not Found. Skipping.
# Processing Record 210 Of Set 210| aklavik.
# Processing Record 211 Of Set 211| berlevag.
# Processing Record 212 Of Set 212| hambantota.
# Processing Record 213 Of Set 213| klaksvik.
# Processing Record 214 Of Set 214| kaitangata.
# Processing Record 215 Of Set 215| maraa.
# Processing Record 216 Of Set 216| comodoro rivadavia.
# Processing Record 217 Of Set 217| altay.
# Processing Record 218 Of Set 218| longyearbyen.
# Processing Record 219 Of Set 219| cuenca.
# Processing Record 220 Of Set 220| nhulunbuy.
# Processing Record 221 Of Set 221| carnarvon.
# Processing Record 222 Of Set 222| helong.
# Processing Record 223 Of Set 223| luxor.
# Processing Record 224 Of Set 224| inirida.
# Processing Record 225 Of Set 225| elat.
# Processing Record 226 Of Set 226| northam.
# Processing Record 227 Of Set 227| san ignacio.
# Processing Record 228 Of Set 228| yunjinghong.
# City Not Found. Skipping.
# Processing Record 229 Of Set 229| kirkland lake.
# Processing Record 230 Of Set 230| maceio.
# Processing Record 231 Of Set 231| tuatapere.
# Processing Record 232 Of Set 232| sucua.
# Processing Record 233 Of Set 233| thompson.
# Processing Record 234 Of Set 234| tumannyy.
# City Not Found. Skipping.
# Processing Record 235 Of Set 235| half moon bay.
# Processing Record 236 Of Set 236| baghdad.
# Processing Record 237 Of Set 237| bubaque.
# Processing Record 238 Of Set 238| melfort.
# Processing Record 239 Of Set 239| roald.
# Processing Record 240 Of Set 240| provideniya.
# Processing Record 241 Of Set 241| sao filipe.
# Processing Record 242 Of Set 242| tabialan.
# City Not Found. Skipping.
# Processing Record 243 Of Set 243| sorong.
# Processing Record 244 Of Set 244| ladario.
# Processing Record 245 Of Set 245| tupiza.
# Processing Record 246 Of Set 246| sentyabrskiy.
# City Not Found. Skipping.
# Processing Record 247 Of Set 247| shimoda.
# Processing Record 248 Of Set 248| urumqi.
# City Not Found. Skipping.
# Processing Record 249 Of Set 249| raton.
# Processing Record 250 Of Set 250| kutulik.
# Processing Record 251 Of Set 251| nantucket.
# Processing Record 252 Of Set 252| raca.
# Processing Record 253 Of Set 253| coracora.
# Processing Record 254 Of Set 254| shupiyan.
# Processing Record 255 Of Set 255| san isidro.
# Processing Record 256 Of Set 256| nikolskoye.
# Processing Record 257 Of Set 257| grindavik.
# Processing Record 258 Of Set 258| samfya.
# Processing Record 259 Of Set 259| sioux lookout.
# Processing Record 260 Of Set 260| nuuk.
# Processing Record 261 Of Set 261| semey.
# Processing Record 262 Of Set 262| hay river.
# Processing Record 263 Of Set 263| havoysund.
# Processing Record 264 Of Set 264| sohag.
# Processing Record 265 Of Set 265| akyab.
# City Not Found. Skipping.
# Processing Record 266 Of Set 266| carauari.
# Processing Record 267 Of Set 267| shurugwi.
# Processing Record 268 Of Set 268| saldanha.
# Processing Record 269 Of Set 269| tazovskiy.
# Processing Record 270 Of Set 270| san patricio.
# Processing Record 271 Of Set 271| listvyanka.
# Processing Record 272 Of Set 272| east london.
# Processing Record 273 Of Set 273| nanortalik.
# Processing Record 274 Of Set 274| stoyba.
# City Not Found. Skipping.
# Processing Record 275 Of Set 275| jacksonville.
# Processing Record 276 Of Set 276| havelock.
# Processing Record 277 Of Set 277| lircay.
# Processing Record 278 Of Set 278| port blair.
# Processing Record 279 Of Set 279| tirlyanskiy.
# Processing Record 280 Of Set 280| wajima.
# Processing Record 281 Of Set 281| barentsburg.
# City Not Found. Skipping.
# Processing Record 282 Of Set 282| russas.
# Processing Record 283 Of Set 283| saint stephen.
# Processing Record 284 Of Set 284| mar del plata.
# Processing Record 285 Of Set 285| puri.
# Processing Record 286 Of Set 286| palana.
# Processing Record 287 Of Set 287| qaanaaq.
# Processing Record 288 Of Set 288| carlsbad.
# Processing Record 289 Of Set 289| husavik.
# Processing Record 290 Of Set 290| alexandria.
# Processing Record 291 Of Set 291| matagami.
# Processing Record 292 Of Set 292| riacho de santana.
# Processing Record 293 Of Set 293| hatillo.
# Processing Record 294 Of Set 294| kalabo.
# Processing Record 295 Of Set 295| rundu.
# Processing Record 296 Of Set 296| san juan del sur.
# Processing Record 297 Of Set 297| mocambique.
# City Not Found. Skipping.
# Processing Record 298 Of Set 298| swellendam.
# Processing Record 299 Of Set 299| qesarya.
# Processing Record 300 Of Set 300| yerbogachen.
# Processing Record 301 Of Set 301| bonfim.
# Processing Record 302 Of Set 302| kamaishi.
# Processing Record 303 Of Set 303| bonavista.
# Processing Record 304 Of Set 304| san quintin.
# Processing Record 305 Of Set 305| belyy yar.
# Processing Record 306 Of Set 306| dezhou.
# Processing Record 307 Of Set 307| sola.
# Processing Record 308 Of Set 308| san lorenzo.
# Processing Record 309 Of Set 309| vestmannaeyjar.
# Processing Record 310 Of Set 310| teknaf.
# Processing Record 311 Of Set 311| samarai.
# Processing Record 312 Of Set 312| dicabisagan.
# Processing Record 313 Of Set 313| atherton.
# Processing Record 314 Of Set 314| nouadhibou.
# Processing Record 315 Of Set 315| leopold.
# Processing Record 316 Of Set 316| korla.
# City Not Found. Skipping.
# Processing Record 317 Of Set 317| alakurtti.
# Processing Record 318 Of Set 318| sao joao do paraiso.
# Processing Record 319 Of Set 319| port hedland.
# Processing Record 320 Of Set 320| umm lajj.
# Processing Record 321 Of Set 321| pangnirtung.
# Processing Record 322 Of Set 322| pitimbu.
# Processing Record 323 Of Set 323| shiyan.
# Processing Record 324 Of Set 324| ankazobe.
# Processing Record 325 Of Set 325| kikwit.
# Processing Record 326 Of Set 326| zambezi.
# Processing Record 327 Of Set 327| abu kamal.
# Processing Record 328 Of Set 328| maddur.
# Processing Record 329 Of Set 329| mount pleasant.
# Processing Record 330 Of Set 330| sudak.
# Processing Record 331 Of Set 331| boulder city.
# Processing Record 332 Of Set 332| gualaca.
# Processing Record 333 Of Set 333| nellikkuppam.
# Processing Record 334 Of Set 334| massarosa.
# Processing Record 335 Of Set 335| tasiilaq.
# Processing Record 336 Of Set 336| barranca.
# Processing Record 337 Of Set 337| amderma.
# City Not Found. Skipping.
# Processing Record 338 Of Set 338| kharp.
# Processing Record 339 Of Set 339| hobyo.
# Processing Record 340 Of Set 340| opuwo.
# Processing Record 341 Of Set 341| gurgan.
# City Not Found. Skipping.
# Processing Record 342 Of Set 342| fare.
# Processing Record 343 Of Set 343| tula.
# Processing Record 344 Of Set 344| mastung.
# Processing Record 345 Of Set 345| sonoita.
# Processing Record 346 Of Set 346| huarmey.
# Processing Record 347 Of Set 347| cherskiy.
# Processing Record 348 Of Set 348| hami.
# Processing Record 349 Of Set 349| maimon.
# City Not Found. Skipping.
# Processing Record 350 Of Set 350| malwan.
# City Not Found. Skipping.
# Processing Record 351 Of Set 351| kandrian.
# Processing Record 352 Of Set 352| zhanaozen.
# Processing Record 353 Of Set 353| at-bashi.
# Processing Record 354 Of Set 354| bonthe.
# Processing Record 355 Of Set 355| tautira.
# Processing Record 356 Of Set 356| chuy.
# Processing Record 357 Of Set 357| djambala.
# Processing Record 358 Of Set 358| peyima.
# Processing Record 359 Of Set 359| tromso.
# Processing Record 360 Of Set 360| axim.
# Processing Record 361 Of Set 361| bambanglipuro.
# Processing Record 362 Of Set 362| yandyki.
# Processing Record 363 Of Set 363| ancud.
# Processing Record 364 Of Set 364| samusu.
# City Not Found. Skipping.
# Processing Record 365 Of Set 365| rafai.
# Processing Record 366 Of Set 366| suao.
# City Not Found. Skipping.
# Processing Record 367 Of Set 367| kungurtug.
# Processing Record 368 Of Set 368| jacareacanga.
# Processing Record 369 Of Set 369| okato.
# Processing Record 370 Of Set 370| lakes entrance.
# Processing Record 371 Of Set 371| moroni.
# Processing Record 372 Of Set 372| cam ranh.
# Processing Record 373 Of Set 373| lasa.
# Processing Record 374 Of Set 374| masjed-e soleyman.
# City Not Found. Skipping.
# Processing Record 375 Of Set 375| mecca.
# Processing Record 376 Of Set 376| mehamn.
# Processing Record 377 Of Set 377| rio formoso.
# Processing Record 378 Of Set 378| hofn.
# Processing Record 379 Of Set 379| beringovskiy.
# Processing Record 380 Of Set 380| buala.
# Processing Record 381 Of Set 381| chifeng.
# Processing Record 382 Of Set 382| zhigalovo.
# Processing Record 383 Of Set 383| kununurra.
# Processing Record 384 Of Set 384| nurlat.
# Processing Record 385 Of Set 385| worland.
# Processing Record 386 Of Set 386| nairn.
# Processing Record 387 Of Set 387| stepnyak.
# Processing Record 388 Of Set 388| deputatskiy.
# Processing Record 389 Of Set 389| arrifes.
# Processing Record 390 Of Set 390| kyshtovka.
# Processing Record 391 Of Set 391| itapeva.
# Processing Record 392 Of Set 392| russell.
# Processing Record 393 Of Set 393| alta floresta.
# Processing Record 394 Of Set 394| hithadhoo.
# Processing Record 395 Of Set 395| vardo.
# Processing Record 396 Of Set 396| pastos bons.
# Processing Record 397 Of Set 397| sao felix do xingu.
# Processing Record 398 Of Set 398| paraiso.
# Processing Record 399 Of Set 399| san felix.
# Processing Record 400 Of Set 400| micheweni.
# Processing Record 401 Of Set 401| rurrenabaque.
# Processing Record 402 Of Set 402| antalaha.
# Processing Record 403 Of Set 403| port-cartier.
# Processing Record 404 Of Set 404| bose.
# Processing Record 405 Of Set 405| katsuura.
# Processing Record 406 Of Set 406| shelburne.
# Processing Record 407 Of Set 407| khatanga.
# Processing Record 408 Of Set 408| cornwall.
# Processing Record 409 Of Set 409| shawville.
# Processing Record 410 Of Set 410| pokhara.
# Processing Record 411 Of Set 411| karratha.
# Processing Record 412 Of Set 412| jackson.
# Processing Record 413 Of Set 413| luleburgaz.
# Processing Record 414 Of Set 414| mitchell.
# Processing Record 415 Of Set 415| troitsko-pechorsk.
# Processing Record 416 Of Set 416| santo antonio do sudoeste.
# Processing Record 417 Of Set 417| leningradskiy.
# Processing Record 418 Of Set 418| xam nua.
# Processing Record 419 Of Set 419| sao miguel do araguaia.
# Processing Record 420 Of Set 420| seoul.
# Processing Record 421 Of Set 421| astipalaia.
# City Not Found. Skipping.
# Processing Record 422 Of Set 422| bathsheba.
# Processing Record 423 Of Set 423| ponta delgada.
# Processing Record 424 Of Set 424| cururupu.
# Processing Record 425 Of Set 425| ortakoy.
# Processing Record 426 Of Set 426| zaysan.
# Processing Record 427 Of Set 427| svetlogorsk.
# Processing Record 428 Of Set 428| bairiki.
# City Not Found. Skipping.
# Processing Record 429 Of Set 429| amapa.
# Processing Record 430 Of Set 430| naugarzan.
# City Not Found. Skipping.
# Processing Record 431 Of Set 431| nacozari.
# Processing Record 432 Of Set 432| zheleznodorozhnyy.
# Processing Record 433 Of Set 433| takoradi.
# Processing Record 434 Of Set 434| kailua.
# Processing Record 435 Of Set 435| oussouye.
# Processing Record 436 Of Set 436| kholmogory.
# Processing Record 437 Of Set 437| paramonga.
# Processing Record 438 Of Set 438| kadykchan.
# City Not Found. Skipping.
# Processing Record 439 Of Set 439| shieli.
# Processing Record 440 Of Set 440| tyrma.
# Processing Record 441 Of Set 441| farah.
# Processing Record 442 Of Set 442| semnan.
# Processing Record 443 Of Set 443| formoso do araguaia.
# City Not Found. Skipping.
# Processing Record 444 Of Set 444| imbituva.
# Processing Record 445 Of Set 445| oranjemund.
# Processing Record 446 Of Set 446| toamasina.
# Processing Record 447 Of Set 447| penon blanco.
# Processing Record 448 Of Set 448| noyabrsk.
# Processing Record 449 Of Set 449| khandyga.
# Processing Record 450 Of Set 450| isangel.
# Processing Record 451 Of Set 451| porto novo.
# Processing Record 452 Of Set 452| baykit.
# Processing Record 453 Of Set 453| inongo.
# Processing Record 454 Of Set 454| havre-saint-pierre.
# Processing Record 455 Of Set 455| mehran.
# Processing Record 456 Of Set 456| skjervoy.
# Processing Record 457 Of Set 457| codrington.
# Processing Record 458 Of Set 458| mazatlan.
# Processing Record 459 Of Set 459| peniche.
# Processing Record 460 Of Set 460| aljezur.
# Processing Record 461 Of Set 461| anloga.
# Processing Record 462 Of Set 462| neyshabur.
# Processing Record 463 Of Set 463| saint combs.
# City Not Found. Skipping.
# Processing Record 464 Of Set 464| xiuyan.
# Processing Record 465 Of Set 465| clyde river.
# Processing Record 466 Of Set 466| powell.
# Processing Record 467 Of Set 467| jatiroto.
# Processing Record 468 Of Set 468| springbok.
# Processing Record 469 Of Set 469| marcona.
# City Not Found. Skipping.
# Processing Record 470 Of Set 470| bozoum.
# Processing Record 471 Of Set 471| pakxan.
# Processing Record 472 Of Set 472| toora-khem.
# Processing Record 473 Of Set 473| moussoro.
# Processing Record 474 Of Set 474| dunedin.
# Processing Record 475 Of Set 475| pasni.
# Processing Record 476 Of Set 476| lazaro cardenas.
# Processing Record 477 Of Set 477| bainbridge.
# Processing Record 478 Of Set 478| glyadyanskoye.
# Processing Record 479 Of Set 479| mercedes.
# Processing Record 480 Of Set 480| inverness.
# Processing Record 481 Of Set 481| college.
# Processing Record 482 Of Set 482| dandong.
# Processing Record 483 Of Set 483| jiaozuo.
# Processing Record 484 Of Set 484| santa isabel do rio negro.
# Processing Record 485 Of Set 485| khonuu.
# City Not Found. Skipping.
# Processing Record 486 Of Set 486| rosetta.
# Processing Record 487 Of Set 487| macon.
# Processing Record 488 Of Set 488| kurumkan.
# Processing Record 489 Of Set 489| touros.
# Processing Record 490 Of Set 490| burica.
# City Not Found. Skipping.
# Processing Record 491 Of Set 491| ames.
# Processing Record 492 Of Set 492| kyra.
# City Not Found. Skipping.
# Processing Record 493 Of Set 493| ostrovnoy.
# Processing Record 494 Of Set 494| los llanos de aridane.
# Processing Record 495 Of Set 495| nioki.
# Processing Record 496 Of Set 496| iganga.
# Processing Record 497 Of Set 497| aasiaat.
# Processing Record 498 Of Set 498| blonduos.
# City Not Found. Skipping.
# Processing Record 499 Of Set 499| maniitsoq.
# Processing Record 500 Of Set 500| lukow.
# Processing Record 501 Of Set 501| olafsvik.
# City Not Found. Skipping.
# Processing Record 502 Of Set 502| san policarpo.
# Processing Record 503 Of Set 503| oksfjord.
# Processing Record 504 Of Set 504| sharan.
# Processing Record 505 Of Set 505| sherbrooke.
# Processing Record 506 Of Set 506| pano polemidia.
# Processing Record 507 Of Set 507| narasannapeta.
# Processing Record 508 Of Set 508| dutse.
# Processing Record 509 Of Set 509| rawson.
# Processing Record 510 Of Set 510| fairbanks.
# Processing Record 511 Of Set 511| flinders.
# Processing Record 512 Of Set 512| zaporizhzhya.
# Processing Record 513 Of Set 513| dreieich.
# Processing Record 514 Of Set 514| riyadh.
# Processing Record 515 Of Set 515| susangerd.
# Processing Record 516 Of Set 516| hualmay.
# Processing Record 517 Of Set 517| hamilton.
# Processing Record 518 Of Set 518| poronaysk.
# Processing Record 519 Of Set 519| margate.
# Processing Record 520 Of Set 520| koshurnikovo.
# Processing Record 521 Of Set 521| meyungs.
# City Not Found. Skipping.
# Processing Record 522 Of Set 522| karaton.
# Processing Record 523 Of Set 523| kihei.
# Processing Record 524 Of Set 524| qandala.
# Processing Record 525 Of Set 525| rawatbhata.
# Processing Record 526 Of Set 526| spearfish.
# Processing Record 527 Of Set 527| talnakh.
# Processing Record 528 Of Set 528| belmonte.
# Processing Record 529 Of Set 529| shubarkuduk.
# Processing Record 530 Of Set 530| shangzhi.
# Processing Record 531 Of Set 531| puerto leguizamo.
# Processing Record 532 Of Set 532| black river.
# Processing Record 533 Of Set 533| santa marta de tormes.
# Processing Record 534 Of Set 534| ucluelet.
# Processing Record 535 Of Set 535| pontianak.
# Processing Record 536 Of Set 536| morgan city.
# Processing Record 537 Of Set 537| olds.
# Processing Record 538 Of Set 538| bandarbeyla.
# Processing Record 539 Of Set 539| san andres.
# Processing Record 540 Of Set 540| coihaique.
# Processing Record 541 Of Set 541| praxedis guerrero.
# Processing Record 542 Of Set 542| khani.
# Processing Record 543 Of Set 543| arman.
# Processing Record 544 Of Set 544| loding.
# Processing Record 545 Of Set 545| aranos.
# Processing Record 546 Of Set 546| campos belos.
# Processing Record 547 Of Set 547| geresk.
# City Not Found. Skipping.
# Processing Record 548 Of Set 548| spring hill.
# Processing Record 549 Of Set 549| humpolec.
# Processing Record 550 Of Set 550| ninghai.
# Processing Record 551 Of Set 551| victoria point.
# Processing Record 552 Of Set 552| rio grande.
# Processing Record 553 Of Set 553| nipawin.
# Processing Record 554 Of Set 554| nsanje.
# Processing Record 555 Of Set 555| kirensk.
# Processing Record 556 Of Set 556| batagay-alyta.
# Processing Record 557 Of Set 557| massaguet.
# Processing Record 558 Of Set 558| parabel.
# Processing Record 559 Of Set 559| ixtapa.
# Processing Record 560 Of Set 560| fairfield.
# Processing Record 561 Of Set 561| yabrud.
# Processing Record 562 Of Set 562| rungata.
# City Not Found. Skipping.
# Processing Record 563 Of Set 563| alofi.
# Processing Record 564 Of Set 564| hasaki.
# Processing Record 565 Of Set 565| fort nelson.
# Processing Record 566 Of Set 566| veracruz.
# Processing Record 567 Of Set 567| broken hill.
# Processing Record 568 Of Set 568| ulaanbaatar.
# Processing Record 569 Of Set 569| high level.
# Processing Record 570 Of Set 570| rocha.
# Processing Record 571 Of Set 571| ban nahin.
# Processing Record 572 Of Set 572| southbridge.
# Processing Record 573 Of Set 573| vallenar.
# Processing Record 574 Of Set 574| uyemskiy.
# Processing Record 575 Of Set 575| patiya.
# Processing Record 576 Of Set 576| mbini.
# Processing Record 577 Of Set 577| haines junction.
# Processing Record 578 Of Set 578| artyk.
# City Not Found. Skipping.
# Processing Record 579 Of Set 579| maxixe.
# Processing Record 580 Of Set 580| jizan.
# Processing Record 581 Of Set 581| jumla.
# Processing Record 582 Of Set 582| pingxiang.
# Processing Record 583 Of Set 583| andarab.
# City Not Found. Skipping.
# Processing Record 584 Of Set 584| phan rang.
# City Not Found. Skipping.
# Processing Record 585 Of Set 585| black forest.
# Processing Record 586 Of Set 586| rassvet.
# Processing Record 587 Of Set 587| noumea.
# Processing Record 588 Of Set 588| chistogorskiy.
# Processing Record 589 Of Set 589| puteyets.
# Processing Record 590 Of Set 590| gao.
# Processing Record 591 Of Set 591| aden.
# Processing Record 592 Of Set 592| poum.
# Processing Record 593 Of Set 593| borogontsy.
# Processing Record 594 Of Set 594| teyateyaneng.
# Processing Record 595 Of Set 595| santa cruz.
# Processing Record 596 Of Set 596| mocuba.
# Processing Record 597 Of Set 597| moche.
# Processing Record 598 Of Set 598| constitucion.
# Processing Record 599 Of Set 599| kalmar.
# Processing Record 600 Of Set 600| berbera.
# City Not Found. Skipping.
# Processing Record 601 Of Set 601| sanming.
# Processing Record 602 Of Set 602| sao gabriel.
# Processing Record 603 Of Set 603| ukiah.
# Processing Record 604 Of Set 604| lebu.
# Processing Record 605 Of Set 605| jiuquan.
# Processing Record 606 Of Set 606| nyurba.
# Processing Record 607 Of Set 607| guekedou.
# City Not Found. Skipping.
# Processing Record 608 Of Set 608| adrar.
# Processing Record 609 Of Set 609| vychegodskiy.
# Processing Record 610 Of Set 610| konongo.
# Processing Record 611 Of Set 611| saint-augustin.
# Processing Record 612 Of Set 612| kirakira.
# Processing Record 613 Of Set 613| viesca.
# Processing Record 614 Of Set 614| temir.
# Processing Record 615 Of Set 615| petropavlovsk-kamchatskiy.
# Processing Record 616 Of Set 616| narrabri.
# Processing Record 617 Of Set 617| olot.
# Processing Record 618 Of Set 618| palora.
# Processing Record 619 Of Set 619| zhezkazgan.
# Processing Record 620 Of Set 620| siva.
# Processing Record 621 Of Set 621| mandurah.
# Processing Record 622 Of Set 622| dejen.
# Processing Record 623 Of Set 623| andenes.
# City Not Found. Skipping.
# Processing Record 624 Of Set 624| fortuna.
# Processing Record 625 Of Set 625| waingapu.
# Processing Record 626 Of Set 626| antofagasta.
# Processing Record 627 Of Set 627| polovinnoye.
# Processing Record 628 Of Set 628| khandbari.
# Processing Record 629 Of Set 629| ust-nera.
# Processing Record 630 Of Set 630| vostok.
# Processing Record 631 Of Set 631| jujuy.
# City Not Found. Skipping.
# Processing Record 632 Of Set 632| dongsheng.
# Processing Record 633 Of Set 633| marrakesh.
# Processing Record 634 Of Set 634| sorland.
# Processing Record 635 Of Set 635| havre de grace.
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_data.dropna(inplace = True) 
print(cities_data)
# Out:
#                      City name Cloudiness Country    Lat     Lng        Date  \
# 0                       Dikson         19      RU  73.51   80.55  1574884138
# 1                      Emerald          0      AU -23.53  148.16  1574884139
# 2                    falealupo
# 3                    Ketchikan          1      US  55.34 -131.65  1574884145
# 4                      vaitupu
# 5                    Quelimane         75      MZ -17.88   36.89  1574884145
# 6               Cabo San Lucas         90      MX  22.89 -109.91  1574883988
# 7                      Cayenne        100      GF   4.94  -52.33  1574884145
# 8                     Tevaitoa         94      PF -16.78  -151.5  1574884146
# 9                        Avera         90      US  33.19  -82.53  1574884146
# 10                   Biskamzha        100      RU  53.45   89.53  1574884146
# 11                  Hammerfest         20      NO  70.66   23.68  1574884146
# 12                     Kahului          1      US  20.89 -156.47  1574884070
# 13                Richards Bay          0      ZA -28.77   32.06  1574884147
# 14                     Ushuaia         40      AR -54.81  -68.31  1574884147
# 15                     Mataura         97      NZ -46.19  168.86  1574884148
# 16                    Souillac        100      FR   45.6    -0.6  1574884148
# 17                      Atuona         53      PF   -9.8 -139.03  1574884148
# 18                 Yellowknife         20      CA  62.45 -114.38  1574884148
# 19                       Kapaa         75      US  22.08 -159.32  1574884148
# 20                    Rosarito         75      CO   4.91  -75.23  1574884148
# 21            illoqqortoormiut
# 22                       Moree          0      AU -29.46  149.84  1574884150
# 23                    Portland         75      US  43.66  -70.25  1574884150
# 24                Kruisfontein         25      ZA    -34   24.73  1574884150
# 25                   Ilulissat         40      GL  69.22   -51.1  1574884151
# 26                     Manyana         67      AU -35.26  150.51  1574884151
# 27                   Egvekinot        100      RU  66.32 -179.17  1574884151
# 28                       Bluff          5      AU -23.58  149.07  1574884151
# 29                    Cidreira        100      BR -30.17  -50.22  1574884152
# ..                         ...        ...     ...    ...     ...         ...
# 606                     Nyurba        100      RU  63.29  118.35  1574884311
# 607                   guekedou
# 608                      Adrar        100      DZ  27.87   -0.29  1574884231
# 609               Vychegodskiy        100      RU  61.25   46.88  1574884312
# 610                    Konongo          0      GH   6.62   -1.21  1574884313
# 611             Saint-Augustin         90      CA  45.63  -73.98  1574884313
# 612                   Kirakira         84      SB -10.46  161.92  1574884313
# 613                     Viesca         75      MX  25.34 -102.81  1574884314
# 614                      Temir          0      KZ  49.14   57.13  1574884314
# 615  Petropavlovsk-Kamchatskiy         90      RU  53.05  158.65  1574884314
# 616                   Narrabri          0      AU -30.33  149.78  1574884314
# 617                       Olot         20      ES  42.18    2.49  1574884139
# 618                     Palora         75      EC   -1.7  -77.97  1574884315
# 619                 Zhezkazgan         68      KZ   47.8   67.71  1574884315
# 620                       Siva         40      GR  35.21   25.04  1574884315
# 621                   Mandurah         67      AU -32.55   115.7  1574884316
# 622                      Dejen        100      ET  10.16   38.15  1574884316
# 623                    andenes
# 624                    Fortuna         75      US   40.6 -124.16  1574884316
# 625                   Waingapu        100      ID  -9.65  120.26  1574884317
# 626                Antofagasta         20      CL -23.65   -70.4  1574884161
# 627                Polovinnoye         98      RU  54.79   65.99  1574884317
# 628                  Khandbari          0      NP  27.38   87.21  1574884318
# 629                   Ust-Nera         98      RU  64.57  143.24  1574884318
# 630                     Vostok        100      RU  46.45  135.83  1574884318
# 631                      jujuy
# 632                  Dongsheng          0      CN  29.72  112.52  1574884319
# 633                  Marrakesh         91      MA  31.63   -7.99  1574884239
# 634                    Sorland         75      NO  67.67   12.69  1574884319
# 635             Havre de Grace         90      US  39.55  -76.09  1574884195
#
#     Humidity Max temp Wind speed
# 0         98   -11.13       4.32
# 1         64     75.2       5.82
# 2
# 3         43     37.4      11.41
# 4
# 5         78     82.4       8.05
# 6         88       77      19.35
# 7         83     80.6       6.93
# 8         81    81.81      13.73
# 9         88     73.4       9.17
# 10        97     4.87       1.83
# 11        85       32      14.99
# 12        54    82.99       8.05
# 13        91    76.73      28.48
# 14        75       50      27.51
# 15        96       55       5.99
# 16        93       54      11.41
# 17        74    79.97      13.42
# 18        83        0       6.93
# 19        83     80.6      11.41
# 20        53     84.2        4.7
# 21
# 22        59     60.8       8.05
# 23        70     48.2       6.93
# 24        90    55.47       3.83
# 25        66     15.8       8.05
# 26       100       66       2.24
# 27        96      8.8       2.01
# 28        72    75.02       10.8
# 29        83    70.59      19.15
# ..       ...      ...        ...
# 606       87     5.05      10.13
# 607
# 608       24     71.6       5.82
# 609       95    23.85       6.67
# 610       82    75.74       2.39
# 611       90       39      11.41
# 612       82    79.97       6.89
# 613       28     82.4       9.17
# 614       84     15.1       6.17
# 615      100     17.6       6.71
# 616       71       64       1.12
# 617       87    57.99       2.24
# 618       94     71.6       5.82
# 619       86    11.17       6.76
# 620       87       61       5.82
# 621       72       64      13.87
# 622       55    64.36       1.16
# 623
# 624      100       43       9.17
# 625       74     82.9       8.23
# 626       63     66.2      12.75
# 627       80    14.23      12.62
# 628       52    41.72       6.38
# 629      100   -46.73       2.04
# 630       97    -8.81       5.55
# 631
# 632       75    38.68       8.55
# 633       51     62.6       5.82
# 634       74     35.6       9.17
# 635       71    57.99      11.41
#
# [636 rows x 9 columns]

# %%
cities_data.count()
# Out:
# City name     636
# Cloudiness    636
# Country       636
# Lat           636
# Lng           636
# Date          636
# Humidity      636
# Max temp      636
# Wind speed    636
# dtype: int64

# %%
cities_data.head(30)
# Out:
#            City name  Cloudiness Country    Lat     Lng          Date  \
# 0             Dikson        19.0      RU  73.51   80.55  1.574884e+09
# 1            Emerald         0.0      AU -23.53  148.16  1.574884e+09
# 2          falealupo         NaN            NaN     NaN           NaN
# 3          Ketchikan         1.0      US  55.34 -131.65  1.574884e+09
# 4            vaitupu         NaN            NaN     NaN           NaN
# 5          Quelimane        75.0      MZ -17.88   36.89  1.574884e+09
# 6     Cabo San Lucas        90.0      MX  22.89 -109.91  1.574884e+09
# 7            Cayenne       100.0      GF   4.94  -52.33  1.574884e+09
# 8           Tevaitoa        94.0      PF -16.78 -151.50  1.574884e+09
# 9              Avera        90.0      US  33.19  -82.53  1.574884e+09
# 10         Biskamzha       100.0      RU  53.45   89.53  1.574884e+09
# 11        Hammerfest        20.0      NO  70.66   23.68  1.574884e+09
# 12           Kahului         1.0      US  20.89 -156.47  1.574884e+09
# 13      Richards Bay         0.0      ZA -28.77   32.06  1.574884e+09
# 14           Ushuaia        40.0      AR -54.81  -68.31  1.574884e+09
# 15           Mataura        97.0      NZ -46.19  168.86  1.574884e+09
# 16          Souillac       100.0      FR  45.60   -0.60  1.574884e+09
# 17            Atuona        53.0      PF  -9.80 -139.03  1.574884e+09
# 18       Yellowknife        20.0      CA  62.45 -114.38  1.574884e+09
# 19             Kapaa        75.0      US  22.08 -159.32  1.574884e+09
# 20          Rosarito        75.0      CO   4.91  -75.23  1.574884e+09
# 21  illoqqortoormiut         NaN            NaN     NaN           NaN
# 22             Moree         0.0      AU -29.46  149.84  1.574884e+09
# 23          Portland        75.0      US  43.66  -70.25  1.574884e+09
# 24      Kruisfontein        25.0      ZA -34.00   24.73  1.574884e+09
# 25         Ilulissat        40.0      GL  69.22  -51.10  1.574884e+09
# 26           Manyana        67.0      AU -35.26  150.51  1.574884e+09
# 27         Egvekinot       100.0      RU  66.32 -179.17  1.574884e+09
# 28             Bluff         5.0      AU -23.58  149.07  1.574884e+09
# 29          Cidreira       100.0      BR -30.17  -50.22  1.574884e+09
#
#     Humidity  Max temp  Wind speed
# 0       98.0    -11.13        4.32
# 1       64.0     75.20        5.82
# 2        NaN       NaN         NaN
# 3       43.0     37.40       11.41
# 4        NaN       NaN         NaN
# 5       78.0     82.40        8.05
# 6       88.0     77.00       19.35
# 7       83.0     80.60        6.93
# 8       81.0     81.81       13.73
# 9       88.0     73.40        9.17
# 10      97.0      4.87        1.83
# 11      85.0     32.00       14.99
# 12      54.0     82.99        8.05
# 13      91.0     76.73       28.48
# 14      75.0     50.00       27.51
# 15      96.0     55.00        5.99
# 16      93.0     54.00       11.41
# 17      74.0     79.97       13.42
# 18      83.0      0.00        6.93
# 19      83.0     80.60       11.41
# 20      53.0     84.20        4.70
# 21       NaN       NaN         NaN
# 22      59.0     60.80        8.05
# 23      70.0     48.20        6.93
# 24      90.0     55.47        3.83
# 25      66.0     15.80        8.05
# 26     100.0     66.00        2.24
# 27      96.0      8.80        2.01
# 28      72.0     75.02       10.80
# 29      83.0     70.59       19.15

# %%
cities_data = cities_data.convert_objects(convert_numeric=True)
cities_data.dtypes
# Out:
# /Users/adeliamanuel/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# City name      object
# Cloudiness    float64
# Country        object
# Lat           float64
# Lng           float64
# Date          float64
# Humidity      float64
# Max temp      float64
# Wind speed    float64
# dtype: object

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_data["Lat"], cities_data["Max temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("Latitude vs. Max Temperature Plot(09/30/19)")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatitudeVSTemperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_data["Lat"], cities_data["Humidity"], marker="o",s=10)

# Incorporate the other graph properties
plt.title("Latitude vs. Humidity Plot(09/30/19)")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatitudevsHumidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_data["Lat"], cities_data["Cloudiness"], marker="o",s=10)

# Incorporate the other graph properties
plt.title("Latitude vs. Cloudiness(09/30/19)")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatitudevsCloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_data["Lat"], cities_data["Wind speed"], marker="o",s=10)

# Incorporate the other graph properties
plt.title("Latitude vs. Wind Speed(09/30/19)")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatitudevsWindSpeed.png")

# Show plot
plt.show()

# %%
#-----------Analysis----------------------
#Figure 1 for latitude vs temperature
# It looks like Latitude and temperature increases at the same time. 
#Or one depends on the other to either increase or decreased.

# Figure 2 latitude vs humidity
# For this figure, looks like the humidity and latitude is pretty high. 
#The regions are more diversified than the first figure.

# Figure 4 latitude vs wind speed
# In this figure, the wind speed is low. Most of the datas are down 20mph.
